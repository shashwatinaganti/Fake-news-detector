# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
import pandas as pd

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-c4c19368-7add-42bf-961e-54f84b064a69" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4c19368-7add-42bf-961e-54f84b064a69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-aae38409-9762-4cd5-a585-37b2540dfa48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aae38409-9762-4cd5-a585-37b2540dfa48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df= pd.read_csv("Fake[1].csv")

# %%
df.shape
df.info()
df.isnull().sum()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# ...

# %%
import pandas as pd
df=pd.read_csv("Fake[1].csv")
print(df.shape)
print(df.info())
print(df.isnull().sum())
df.head()
# Out:
# (23481, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB
# None
# title      0
# text       0
# subject    0
# date       0
# dtype: int64
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# ...

# %%
df['label']='Fake'

# %%
df.head()
x=df['text']
y=df['label']
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.25,  random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df['label'] = 'FAKE'  # if your dataset includes both real & fake, you'd split them before

# Split into X and y
X = df['text']
y = df['label']

# Now split into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)
tfidf_train = vectorizer.fit_transform(X_train)
tfidf_test = vectorizer.transform(X_test)

# %%
print(y_train.unique())
# Out:
# ['FAKE']

# %%
from google.colab import files
uploaded= files.upload

# %%
import pandas as pd

# Load fake news dataset
fake_df = pd.read_csv("Fake[1].csv")
fake_df["label"] = "FAKE"

# Load real news dataset
real_df = pd.read_csv("True[1].csv")
real_df["label"] = "REAL"

# Combine datasets
df = pd.concat([fake_df, real_df], axis=0)
df = df.sample(frac=1).reset_index(drop=True)  # Shuffle the dataset

# %%
# Load datasets
fake_df = pd.read_csv('Fake[1].csv')
true_df = pd.read_csv('True[1].csv')

# Add labels
fake_df['label'] = 1
true_df['label'] = 0

# Combine them
df = pd.concat([fake_df, true_df], ignore_index=True)

# %%
# Shuffle
df = df.sample(frac=1).reset_index(drop=True)

# Check
print(df['label'].value_counts())
print(df.isnull().sum())
# Out:
# label
# 1    23481
# 0    21417
# Name: count, dtype: int64
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
x = df['text']  # You could also use 'title' or a combination
y = df['label']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)
tfidf_train = vectorizer.fit_transform(X_train)
tfidf_test = vectorizer.transform(X_test)

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

pac = PassiveAggressiveClassifier(max_iter=50)
pac.fit(tfidf_train, y_train)
# Out:
# PassiveAggressiveClassifier(max_iter=50)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

y_pred = pac.predict(tfidf_test)
score = accuracy_score(y_test, y_pred)
print(f'Accuracy: {round(score*100,2)}%')

conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
# Out:
# Accuracy: 99.39%
# [[4211   22]
#  [  33 4714]]

# %%
pip install newsapi-python

# %%
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key='e72d67e054d84e7d982f991a73066cd9')

# %%
query = "NASA moon mission"

all_articles = newsapi.get_everything(q=query,
                                      language='en',
                                      sort_by='relevancy',
                                      page_size=5)

# Get headlines and content
for article in all_articles['articles']:
    print("Title:", article['title'])
    print("Content:", article['content'])
    print()
# Out:
# Title: NASA Scraps Promise to Land ‘First Woman and Person of Color’ on the Moon
# Content: After years of promoting its return to the Moon with the promise of inclusion, NASA has concealed its well-publicized intent of landing a diverse crew on the lunar surface as part of the Artemis prog… [+2427 chars]
#
# Title: Lunar Lander Captures First High-Definition Video of a Sunset on the Moon
# Content: The Blue Ghost lander bid farewell to the Moon by gently going into that cold lunar night. Before ending its mission on the lunar surface, Blue Ghost watched a beautiful sunset, capturing the glow of… [+2775 chars]
#
# Title: Firefly Bids Farewell to Its Lunar Lander After 14 Days on the Moon
# Content: Firefly’s Blue Ghost lander went gently into the lunar night after spending a full lunar day on the Moon, gathering data and beaming it back to Earth as part of the company’s first commercial drop-of… [+2681 chars]
#
# Title: Watch this ultra-detailed animation of the seafloor
# ...

# %%
# Example: Predict one article
title = article['title']
content = article['content']

# Combine title and content
news_text = str(title) + " " + str(content)

# Transform using your TF-IDF vectorizer
transformed = vectorizer.transform([news_text])

# Predict
prediction = pac.predict(transformed)
print("Prediction:", "Fake" if prediction[0] == 0 else "Real")
# Out:
# Prediction: Real

# %%
def check_news_via_search(query):
    all_articles = newsapi.get_everything(q=query,
                                          language='en',
                                          sort_by='relevancy',
                                          page_size=5)

    for article in all_articles['articles']:
        title = article['title']
        content = article['content']
        news_text = str(title) + " " + str(content)

        transformed = vectorizer.transform([news_text])
        prediction = pac.predict(transformed)

        print("🔎 Title:", title)
        print("📝 Content:", content)
        print("🚨 Prediction:", "🟥 FAKE" if prediction[0] == 0 else "🟩 REAL")
        print("-" * 60)

# %%
import requests

params = {
  "engine": "google",
  "q": "India Elections 2024",
  "api_key": "91e4b3762a30068ef7a0e9e6eb50bdd56ca61d1cfcc1e770d432cc0ea775e015"
}

response = requests.get("https://serpapi.com/search", params=params)
results = response.json()

# %%
news_articles = results.get("news_results", [])

for article in news_articles:
    title = article.get("title", "")
    snippet = article.get("snippet", "")
    content = title + " " + snippet

    # Send content to your fake news model

# %%
text_vector = vectorizer.transform([content])

# %%
prediction = pac.predict(text_vector)

if prediction[0] == 0:
    print("🔴 FAKE NEWS")
else:
    print("🟢 REAL NEWS")
# Out:
# 🟢 REAL NEWS

# %%
def predict_news_from_serpapi(results):
    for article in results.get("news_results", []):
        content = article.get("title", "") + " " + article.get("snippet", "")
        text_vector = vectorizer.transform([content])
        prediction = pac.predict(text_vector)

        print("📰", article.get("title"))
        print("Prediction:", "🟢 REAL" if prediction[0] == 1 else "🔴 FAKE", "\n")
